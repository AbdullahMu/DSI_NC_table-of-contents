# %% [markdown]
# ```
# ---
# title: API Review with Foursquare API
# type:  lesson + lab + demo
# duration: "1:25"
# creator:
#     name: David Yerrington
#     city: SF
# ---
# ```
# <img src="https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png" style="float: left; margin: 10px">
#
# #  API Demo / Lab + NLP
# Week 8 | 1.3
#
#
# <img src="https://snag.gy/RNAEgP.jpg" width="600">
#
# Can we correctly identify which of these two old men tweeted what?

# %% [markdown]
# ## (5 mins) Opening
#
# Today we are going to attempt to classify wether a tweet comes from Trump, or Sanders.  We are going to:
#
# - Create a developer account on Twitter
# - Create a method to pull a list of tweets from the Twitter API
# - Perform proper preprocessing on our text
# - Engineer sentiment feature in our dataset using TextBlob
# - Explore supervised classification techniques

# %% [markdown]
# ## Twitter API Developer Registration
#
# If you haven't registered a Twitter account yet, this is a requirement in order to have a "developer" account.
#
# [Twitter Rest API](https://dev.twitter.com/rest/public)

# %% [markdown]
# ## Create an "App"
#
# ![](https://snag.gy/HPBQbJ.jpg)
#
# We now will now go to Twitter and register an "app" [apps.twitter.com](https://apps.twitter.com/), just like we did for Foursquare.  After we set up our app, we will only need to reference the cooresponding keys Twitter generates for our app.  These are the keys that we will use with our application to communicate with the Twitter API.

# %% [markdown]
# ## Install Python Twitter API library
#
# Someone was nice enough to build a nice libary for us in Python that we only need to plug in our keys and start collecting data with.  The library we will be using is provided by [Python Twitter Tools](http://mike.verdone.ca/twitter/).
#
# To install it, just run the next frame (there is no conda package).

# %%
# !pip install twitter python-twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
#     100% |████████████████████████████████| 61kB 4.2MB/s
# Collecting python-twitter
#   Downloading python-twitter-3.1.tar.gz (80kB)
#     100% |████████████████████████████████| 81kB 4.2MB/s
# Collecting future (from python-twitter)
#   Downloading future-0.15.2.tar.gz (1.6MB)
#     100% |████████████████████████████████| 1.6MB 380kB/s
# Requirement already satisfied (use --upgrade to upgrade): requests in /Users/davidyerrington/anaconda/lib/python2.7/site-packages (from python-twitter)
# Collecting requests-oauthlib (from python-twitter)
#   Downloading requests_oauthlib-0.6.2-py2.py3-none-any.whl
# Collecting oauthlib>=0.6.2 (from requests-oauthlib->python-twitter)
#   Downloading oauthlib-2.0.0.tar.gz (122kB)
#     100% |████████████████████████████████| 122kB 3.8MB/s
# Building wheels for collected packages: python-twitter, future, oauthlib
# done
#   Stored in directory: /Users/davidyerrington/Library/Caches/pip/wheels/22/1e/2e/506871fa7dc610616948e70812d5e2518cd89c13f757b98f6c
# done
#   Stored in directory: /Users/davidyerrington/Library/Caches/pip/wheels/11/c5/d2/ad287de27d0f0d646f119dcffb921f4e63df128f28ab0a1bda
# done
#   Stored in directory: /Users/davidyerrington/Library/Caches/pip/wheels/e4/e1/92/68af4b20ac26182fbd623647af92118fc4cdbdb2c613030a67
# Successfully built python-twitter future oauthlib
# Installing collected packages: twitter, future, oauthlib, requests-oauthlib, python-twitter
# Successfully installed future-0.15.2 oauthlib-2.0.0 python-twitter-3.1 requests-oauthlib-0.6.2 twitter-1.17.1

# %% [markdown]
# ## Some Boring Twitter Rules
#
# Twitter says they will rate limit your requests:
#
# >When using application-only authentication, rate limits are determined globally for the entire application. If a method allows for 15 requests per rate limit window, then it allows you to make 15 requests per window — on behalf of your application. This limit is considered completely separately from per-user limits. https://dev.twitter.com/rest/public/rate-limiting
#
# Here's a quick overview of what Twitter says are "the rulez":
#
# ![](https://snag.gy/yJ6vIH.jpg)

# %% [markdown]
# ## About those Keys: OAuth Review
#
# ![](https://g.twimg.com/dev/documentation/image/appauth_0.png)

# %% [markdown]
# ## What's going on here?  Take a minute..

# %% [markdown]
# ## Our Application Keys
#
# Take note of our application keys that we will be using with our little application that will be connecting to Twitter and mining Tweets from the official Bernie Sanders and Donald Trump twitter accounts.
#
# ![](https://snag.gy/H1djQK.jpg)

# %% [markdown]
# ## Tweet Miner Class Setup
#
# The following code is meant to get us up and running with connectivity to twitter, and the ability to make requests and easily transform the JSON responses to DataFrames.  We will be using object oriented Python in order to organize our code.  We may go into review since this was a topic we covered earlier in the class but we can review it during the lab for those who want to know more about it.
#
#
# > "request_limit" is used in this class to limit the number of tweets that are pulled per instance request.  Setting it to something lower until you've worked the bugs out of your request, and captured the data you want, is essential to avoiding any rate limit blocks.
#
# #### Key Setup
#
# - **consumer_key** - Find this in your app page under the "Keys and Access Tokens"
# - **consumer_secret** - Right under **consumer_key** in the "Keys and Access Tokens" tab
# - **access_token_key** - You will need to click the "generate tokens" button to get this
# - **access_token_secret** - Also available after "generate tokens" is pressed

# %%
twitter_keys = {
    'consumer_key':        'KmN03M1X1pImZ43sqdIu4yfnE',
    'consumer_secret':     'ePlIrIX5VXbZnO7DBu1RbFlw5lOai9dQr9n5TZb6vxnIdrr5Fz',
    'access_token_key':    '185036086-Q7K5IjuSoQZJwSIqD0wyHf6t62iPKatmfaPkriAM',
    'access_token_secret': 'cYpQz3xWHQbLplOj8iSeiNSOmMcsTOXmWcKMrJ9buLj5d'
}

api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret']
)

api.GetUserTimeline(?)

# %%
import twitter, re, datetime, pandas as pd

class twitterminer():

    request_limit   =   20    
    api             =   False
    data            =   []
    
    twitter_keys = {
        'consumer_key':        'KmN03M1X1pImZ43sqdIu4yfnE',
        'consumer_secret':     'ePlIrIX5VXbZnO7DBu1RbFlw5lOai9dQr9n5TZb6vxnIdrr5Fz',
        'access_token_key':    '185036086-Q7K5IjuSoQZJwSIqD0wyHf6t62iPKatmfaPkriAM',
        'access_token_secret': 'cYpQz3xWHQbLplOj8iSeiNSOmMcsTOXmWcKMrJ9buLj5d'
    }
    
    def __init__(self,  request_limit = 20):
        
        self.request_limit = request_limit
        
        # This sets the twitter API object for use internall within the class
        self.set_api()
        
    def set_api(self):
        
        self.api = twitter.Api(
            consumer_key         =   self.twitter_keys['consumer_key'],
            consumer_secret      =   self.twitter_keys['consumer_secret'],
            access_token_key     =   self.twitter_keys['access_token_key'],
            access_token_secret  =   self.twitter_keys['access_token_secret']
        )

    def mine_user_tweets(self, user="dyerrington", mine_rewteets=False, max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  0
        
        while page <= max_pages:
            
            if last_tweet_id:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.request_limit, max_id=last_tweet_id - 1)        
            else:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.request_limit)
                
            for item in statuses:

                mined = {
                    'tweet_id': item.id,
                    'handle': item.user.name,
                    'retweet_count': item.retweet_count,
                    'text': item.text,
                    'mined_at': datetime.datetime.now(),
                    'created_at': item.created_at,
                }
                
                last_tweet_id =   item.id
                data.append(mined)
                
            page          +=  1
            
        return data

# %% [markdown]
# ## Does anyone remember how we "instantiate" a new instance of this class?
#
# **Bonus bonus** How do we call the method to *mine_user_tweets()*?

# %%
# twitter ids:  realDonaldTrump, berniesanders
# Let's test this out here..
miner = twitterminer(request_limit=200)
sanders = miner.mine_user_tweets(user="berniesanders", max_pages=5)

# %%
df = pd.DataFrame(sanders)
df["tweet_id"].value_counts()
# Out:
# 758346361393655808    1
# 776507334738710529    1
# 743451632650723329    1
# 768626058622930944    1
# 770631570642366464    1
# 768078475387338752    1
# 750770008154714113    1
# 738525888141107200    1
# 753982394617638916    1
# 733441885218308096    1
# 745985033626804226    1
# 731893684354981888    1
# 736995427652767744    1
# 757771807701266432    1
# 758405138558033921    1
# 749362783213330433    1
# 777176037776130048    1
# 751807900549472257    1
# 765564970763366401    1
# 737347348574011392    1
# 733084849230077954    1
# 741797689369579521    1
# 740918095661961216    1
# 770401018198777858    1
# 745720776842567681    1
# 749256829117444096    1
# 771792432384004097    1
# 770754509379346432    1
# 738173810071900160    1
# 770631412756180993    1
#                      ..
# 730756163994705923    1
# 745756399393603584    1
# 773593154746482688    1
# 741393533202894850    1
# 775792193663406084    1
# 738021814983491584    1
# 772608074603384833    1
# 757777881695133696    1
# 776882976739168260    1
# 743601708295659521    1
# 771341475221209089    1
# 767787663487229952    1
# 768614489490984962    1
# 735845719379058689    1
# 757214621228863489    1
# 737348859408437248    1
# 732223950613323779    1
# 759764675433144320    1
# 755402592071487488    1
# 730562443194318849    1
# 745357634526601216    1
# 742437160725315584    1
# 738760506400346113    1
# 751556737602248704    1
# 760592359692263424    1
# 738472280271917057    1
# 737824419205120000    1
# 762381636658876416    1
# 760539624695476224    1
# 734479207032455168    1
# Name: tweet_id, dtype: int64

# %% [markdown]
# ##  Now we create some training data
#
# We will have to munge a little bit in order to get our "mined" data from the Twitter API.
#
#  - Mine Trump Tweets
#  - Create DataFrame
#  - Mine Sanders Tweets
#  - Append to DataFrame

# %%
# we only need to "instantiate" once.  Then we can call mine_user_tweets as much as we want.
miner = twitterminer(request_limit=400)
trump_tweets = miner.mine_user_tweets("realDonaldTrump")

# %%
trump_df = pd.DataFrame(trump_tweets)
trump_df.head(10)
# Out:
#                        created_at           handle                   mined_at  \
# 0  Mon Sep 19 19:52:00 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072053
# 1  Mon Sep 19 16:53:42 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072069
# 2  Mon Sep 19 16:41:15 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072076
# 3  Mon Sep 19 16:32:32 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072080
# 4  Mon Sep 19 12:27:28 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072088
# 5  Mon Sep 19 12:14:59 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072094
# 6  Mon Sep 19 11:02:30 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072099
# 7  Mon Sep 19 02:32:03 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072104
# 8  Mon Sep 19 02:30:34 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072109
# 9  Sun Sep 18 21:11:48 +0000 2016  Donald J. Trump 2016-09-19 14:39:37.072117
#
#    retweet_count                                               text  \
# 0           3061  Philly FOP Chief On Presidential Endorsement: ...
# 1           6163  Hillary Clinton's weakness while she was Secre...
# 2          10104  Once again someone we were told is ok turns ou...
# 3          10503  Great job once again by law enforcement! We ar...
# 4           6137  "@TarukMatuk: @CNN @FoxNews @realDonaldTrump @...
# 5           3699  "@AngPiazza: @foxandfriends  @realDonaldTrump ...
# 6           1778     Will be on @foxandfriends at 7:02 A.M.  Enjoy.
# 7          11494  Terrible attacks in NY, NJ and MN this weekend...
# 8          16274  Under the leadership of Obama &amp; Clinton, A...
# 9          10959  HAPPY BIRTHDAY - to the United States Air Forc...
#
#              tweet_id
# 0  777958440211771392
# 1  777913567676866560
# 2  777910435425226753
# 3  777908242538196992
# 4  777846568741441536
# 5  777843428449251328
# 6  777825186758418432
# 7  777696726933180416
# 8  777696356211326976
# 9  777616135856545792

# %% [markdown]
# ## Any interesting ngrams going on with Trump?

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,4))

# Pulls all of trumps tweet text's into one giant string
summaries = "".join(trump_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'https co', 116),
#  (u'thank you', 25),
#  (u'will be', 13),
#  (u'imwithyou https', 13),
#  (u'imwithyou https co', 13),
#  (u'americafirst https', 12),
#  (u'americafirst https co', 12),
#  (u'of the', 10),
#  (u'to the', 10),
#  (u'crooked hillary', 9),
#  (u'for the', 9),
#  (u'america great', 8),
#  (u'maga https', 8),
#  (u'maga https co', 8),
#  (u'hillary clinton', 8),
#  (u'great again', 8),
#  (u'america great again', 7),
#  (u'make america', 7),
#  (u'last night', 6),
#  (u'make america great again', 6)]

# %%
sanders_tweets = miner.mine_user_tweets("berniesanders")

# %%
all_tweets = pd.DataFrame(trump_tweets + sanders_tweets)
all_tweets.handle.value_counts()
# all_tweets.groupby("handle").size()
# Out:
# Bernie Sanders     200
# Donald J. Trump    200
# Name: handle, dtype: int64

# %% [markdown]
# ## Preprocessing our Tweets
#
# In order to do classfication recall that we need a set of features.  Our features are literally what our presidential hopefulls say on Twitter.
#
# We will need to:
# - Vectorize input text data
# - Intialize a model (let's try Logistic regression)
# - Train / Predict / Cross Validate
# - Score / Evaluate

# %%
from sklearn.linear_model import LogisticRegression

# Preprocess our text data to Tfidf
tfv = TfidfVectorizer(lowercase=True, strip_accents='unicode')
X_all = tfv.fit_transform(all_tweets['text'])

# Setup logistic regression (or try another classification method here)
estimator = LogisticRegression()
estimator.fit(X_all, all_tweets['handle'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ## Check Prediction vs Random Sanders Tweet

# %%
# Prep our source as TfIdf vectors
source_test = [
    "Demanding that the wealthy and the powerful start paying their fair share of taxes that's exactly what the American people want.",
    "Crooked Hillary is spending tremendous amounts of Wall Street money on false ads against me. She is a very dishonest person!"
]

############
# NOTE:  Do not re-initialize the tfidf vectorizor or the feature space willbe overwritten and
# hence your transform will not match the number of features you trained your model on.
#
# This is why you only need to "transform" since you already "fit" previously
#
####

X_all = tfv.transform(source_test)

# Predict using previously trained logist regression `estimator`
estimator.predict_proba(X_all)
# Out:
# array([[ 0.74252626,  0.25747374],
#        [ 0.33364651,  0.66635349]])

# %% [markdown]
# ## Lab Time
#
# We would like you to perform an analysis using a proper cross validation.  Also, try classfication using other models.

# %% [markdown]
# ### 1. Implement the same analysis using more data.
#
# Experiment with using more data.  The API may not like that you are blowing through their limits so definitely be careful.  Try to grab only what you need 1x, then work on the copy of the objects that are returned.  Read the documents about rate limits and see if you can get enough without hitting the rate limit.  Are there any options availabl in the API to avoid such a problem?

# %%
# We deviate from trump / sanders using student tweets here to illustrate the NLP pipeine with twitter data

twitter_handles = ["sayambuiar", "five_virtues", "vnessified"]
tweets = {}

for twitter_handle in twitter_handles:
    print "Mining tweets for: ", twitter_handle
    miner = twitterminer(request_limit=200)
    tweets[twitter_handle] = miner.mine_user_tweets(user=twitter_handle, max_pages=10)
# Out:
# Mining tweets for:  sayambuiar

# %%
student_tweets = pd.DataFrame(tweets['sayambuiar'])
student_tweets = student_tweets.append(pd.DataFrame(tweets['five_virtues']))
student_tweets = student_tweets.append(pd.DataFrame(tweets['vnessified']))

# %%
student_tweets.handle.value_counts()
# Out:
# Vanessa Grass    2197
# Cecilia L.       1022
# deniise           590
# Name: handle, dtype: int64

# %%
# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(3,5), stop_words="english")

# Pulls all of trumps tweet text's into one giant string
summaries = "".join(student_tweets[student_tweets['handle'] == "Vanessa Grass"]['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'san francisco ca', 16),
#  (u'francisco ca http', 12),
#  (u'san francisco ca http', 12),
#  (u'll let know', 4),
#  (u'heard good things', 3),
#  (u'kolsvein oh yea', 3),
#  (u'hq san francisco ca', 3),
#  (u'onthefirefly thanks james', 3),
#  (u'hq san francisco', 3),
#  (u'fav tweet http', 2),
#  (u'public speaking workshop', 2),
#  (u'plaid collar privilege', 2),
#  (u'francisco international airport sfo', 2),
#  (u'benedictfritz seanwolter http', 2),
#  (u'themillsf san francisco ca', 2),
#  (u'lying lack self awareness', 2),
#  (u'hbo silicon valley', 2),
#  (u'thanks james onthefirefly', 2),
#  (u'look like https', 2),
#  (u'really going miss', 2)]

# %%
tfv = TfidfVectorizer(lowercase=True, strip_accents='unicode', stop_words='english')
X_all = tfv.fit_transform(student_tweets['text'])

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_all, student_tweets['handle'], test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

# estimator = MultinomialNB()
estimator = LogisticRegression()
estimator.fit(X_train, y_train)

probabilities = estimator.predict_proba(X_test)
predictions = estimator.predict(X_test)

# %%
estimator.score(X_test, y_test)
# Out:
# 0.71280827366746224

# %%
from sklearn.metrics import classification_report, confusion_matrix

print classification_report(y_test, predictions)
# Out:
#              precision    recall  f1-score   support
#
#  Cecilia L.       0.94      0.52      0.67       338
# Vanessa Grass       0.66      0.99      0.79       695
#     deniise       1.00      0.14      0.25       224
#
# avg / total       0.80      0.71      0.66      1257

# %%
# Confusion Matrix
print confusion_matrix(y_test, predictions)
# Out:
# [[175 163   0]
#  [  6 689   0]
#  [  5 187  32]]

# %%
probabilities = estimator.predict_proba(X_all)

student_tweets['cecilia_proba'] = probabilities[:, 0]
student_tweets['vanessa_proba'] = probabilities[:, 1]
student_tweets['deniise_proba'] = probabilities[:, 2]

# %%
student_tweets[(student_tweets['handle'] == 'Cecilia L.') & (student_tweets['vanessa_proba'] > .5)].sort_values(by="vanessa_proba", ascending=False)
# Out:
#                          created_at      handle                   mined_at  \
# 11   Thu Sep 05 06:50:25 +0000 2013  Cecilia L. 2016-09-19 16:18:32.247347
# 47   Tue Feb 08 17:15:50 +0000 2011  Cecilia L. 2016-09-19 16:18:32.247460
# 4    Wed Apr 09 06:53:20 +0000 2014  Cecilia L. 2016-09-19 16:18:32.247324
# 584  Mon Mar 02 03:59:46 +0000 2009  Cecilia L. 2016-09-19 16:18:33.238442
# 9    Sat Oct 05 22:17:03 +0000 2013  Cecilia L. 2016-09-19 16:18:32.247341
# 824  Tue Oct 14 04:06:27 +0000 2008  Cecilia L. 2016-09-19 16:18:33.976438
# 827  Wed Oct 08 15:13:09 +0000 2008  Cecilia L. 2016-09-19 16:18:33.976450
# 463  Thu Aug 06 06:33:56 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237844
# 699  Mon Dec 29 06:24:30 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657248
# 88   Sat Dec 11 23:45:44 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247590
# 719  Tue Dec 23 08:46:42 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657315
# 226  Mon Jul 26 21:27:39 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782862
# 963  Thu Apr 17 18:36:21 +0000 2008  Cecilia L. 2016-09-19 16:18:33.976924
# 321  Mon Jan 11 08:03:41 +0000 2010  Cecilia L. 2016-09-19 16:18:32.783247
# 64   Sat Jan 08 04:48:36 +0000 2011  Cecilia L. 2016-09-19 16:18:32.247515
# 199  Sat Aug 21 22:53:52 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247950
# 478  Wed Jul 08 23:30:51 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237899
# 694  Fri Jan 02 06:42:32 +0000 2009  Cecilia L. 2016-09-19 16:18:33.657232
# 215  Wed Aug 04 16:43:54 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782819
# 956  Mon May 19 19:00:37 +0000 2008  Cecilia L. 2016-09-19 16:18:33.976900
# 526  Wed Apr 29 06:16:20 +0000 2009  Cecilia L. 2016-09-19 16:18:33.238072
# 252  Fri Jun 11 03:09:28 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782967
# 311  Wed Jan 27 00:32:31 +0000 2010  Cecilia L. 2016-09-19 16:18:32.783199
# 269  Sun Apr 25 19:04:28 +0000 2010  Cecilia L. 2016-09-19 16:18:32.783036
# 212  Thu Aug 05 06:20:23 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782806
# 687  Tue Jan 06 02:48:07 +0000 2009  Cecilia L. 2016-09-19 16:18:33.657208
# 581  Thu Mar 05 18:22:39 +0000 2009  Cecilia L. 2016-09-19 16:18:33.238425
# 481  Thu Jul 02 19:25:37 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237910
# 559  Thu Mar 26 03:14:39 +0000 2009  Cecilia L. 2016-09-19 16:18:33.238296
# 243  Mon Jul 12 16:53:24 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782932
# ..                              ...         ...                        ...
# 439  Sat Aug 29 05:11:11 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237755
# 92   Wed Dec 08 23:19:26 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247603
# 697  Wed Dec 31 04:36:20 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657242
# 277  Tue Mar 30 00:58:31 +0000 2010  Cecilia L. 2016-09-19 16:18:32.783068
# 742  Fri Dec 12 06:45:07 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657391
# 132  Tue Oct 26 20:57:50 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247733
# 375  Fri Oct 16 03:06:41 +0000 2009  Cecilia L. 2016-09-19 16:18:32.783612
# 129  Sat Oct 30 20:18:37 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247723
# 32   Wed Aug 03 02:29:32 +0000 2011  Cecilia L. 2016-09-19 16:18:32.247413
# 65   Tue Jan 04 00:48:13 +0000 2011  Cecilia L. 2016-09-19 16:18:32.247518
# 864  Tue Sep 16 21:08:50 +0000 2008  Cecilia L. 2016-09-19 16:18:33.976595
# 103  Wed Nov 24 21:35:24 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247638
# 249  Mon Jun 14 04:20:22 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782955
# 188  Thu Aug 26 15:55:46 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247918
# 337  Thu Dec 10 03:05:13 +0000 2009  Cecilia L. 2016-09-19 16:18:32.783472
# 444  Mon Aug 24 23:38:50 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237774
# 202  Tue Aug 17 02:11:44 +0000 2010  Cecilia L. 2016-09-19 16:18:32.782762
# 725  Fri Dec 19 08:04:57 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657335
# 854  Sat Sep 20 23:57:44 +0000 2008  Cecilia L. 2016-09-19 16:18:33.976551
# 524  Thu May 07 04:48:50 +0000 2009  Cecilia L. 2016-09-19 16:18:33.238065
# 583  Tue Mar 03 06:39:06 +0000 2009  Cecilia L. 2016-09-19 16:18:33.238436
# 430  Fri Sep 04 05:32:54 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237724
# 438  Sun Aug 30 19:29:31 +0000 2009  Cecilia L. 2016-09-19 16:18:33.237752
# 159  Mon Sep 27 18:30:36 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247820
# 307  Thu Feb 04 21:35:02 +0000 2010  Cecilia L. 2016-09-19 16:18:32.783183
# 37   Thu Apr 21 17:35:27 +0000 2011  Cecilia L. 2016-09-19 16:18:32.247429
# 769  Mon Nov 24 06:08:26 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657479
# 728  Wed Dec 17 21:22:41 +0000 2008  Cecilia L. 2016-09-19 16:18:33.657345
# 123  Wed Nov 03 16:03:20 +0000 2010  Cecilia L. 2016-09-19 16:18:32.247703
# 338  Mon Dec 07 23:53:55 +0000 2009  Cecilia L. 2016-09-19 16:18:32.783476
#
#      retweet_count                                               text  \
# 11               0                             http://t.co/Pin2Da9W4m
# 47               0  Haha RT @someecards Wanted to thank you in adv...
# 4                0  ♫ Nirvana – Sam Smith http://t.co/uPC7lLsHzB #...
# 584              0  Looking forward to watching the Dark Knight on...
# 9                0  ♫ Sacred and profane by Cecilia Lam http://t.c...
# 824              0                          yes SY i am in austin now
# 827              0  just finished watching 2001 space odyssey last...
# 463              0  http://bit.ly/10Va67\n What an astounding and ...
# 699              0                   Just finished watching Superman.
# 88               0  Fun!  http://www.bbc.co.uk/bbcone/wallaceandgr...
# 719              0  Is a 36 min layover in Philly actually reasona...
# 226              0  love this idea of "SuperBetter", the game to m...
# 963              0         you know, i'm actually, REALLY sick of it.
# 321              0  Thanks for sharing, LS! (I'm assuming you don'...
# 64               0     Starting planning.  Definitely not having fun.
# 199              0  @LeticiaBritosC Yes I agree it is ABSOLUTELY c...
# 478              0  @cantoincucina the coolin from barber's set of...
# 694              0                                 FULL of good food.
# 215              0          Do I know anyone that lives in charlotte?
# 956              0     @saikoxpooh congrats!!! that's great!   in LA?
# 526              0  @corayoga thanks cora.  i've also been trying ...
# 252              0  Yes, I did. I just added "wedding" as a tag on...
# 311              0  So you're gonna laugh, but I need to know wher...
# 269              0   My first shooting range experience with a Bersa!
# 212              0        I sort of love Radiolab. Thanks @jonlee554!
# 687              0                               Just end it already!
# 581              0  @lindasusan thanks so much for livetwittering!...
# 481              0  @sarahcove amazing that gay rights activists a...
# 559              0  Yes, you'd be right if you guessed I'm in Scot...
# 243              0  I have a friend who doesn't say thank you when...
# ..             ...                                                ...
# 439              0                                         Traveling.
# 92               0  I love someecards. I know some people for whic...
# 697              0  my ninja and his girlfriend are cooking.  i'm ...
# 277              0  Does anyone else get the weird feeling that th...
# 742              0  Can I just say - I'm watching C-SPAN at the ho...
# 132              0  You've got to be kidding me. You're kidding me...
# 375              0  Did taxi ridership suddenly increase or someth...
# 129              0  At kitari sushi, calistoga. Already unsatisfie...
# 32               0  You know, the only way to beat the #sfmuni sys...
# 65               0  @vickiloo82 check out the article in the nyt. ...
# 864              0                         @saikoxpooh thats awesome!
# 103              0  Going through security at OAK was painless. My...
# 249              0  Unbelievable. Wow. What am I doing with my lif...
# 188              0  Ah, the telephone. How I hate that I don't get...
# 337              0       YES! Chicken piccata tonight!  I'm so lucky!
# 444              0  Got a suggestion for a REALLY easy and tasty d...
# 202              0  Does it smell like horse manure in the mission...
# 725              0  i got a new water bottle to replace my Sigg bo...
# 854              0                                     my back hurts.
# 524              0  In Iowa/Nebraska/South Dakota (yes, all at the...
# 583              0  @jresuello are you SERIOUS? You're STILL there...
# 430              0  New haircut!  Very excited about it.  Nope, ca...
# 438              0  Wake up. Drive Malden to Chinatown. Inglorious...
# 159              0  Am I a bad adult and musician if I really real...
# 307              0  Testing the healing powers of Brahms. And a wa...
# 37               0  Thanks phone for your service, but you're way ...
# 769              0  i just saw iron man with nate on netflix. love...
# 728              0  I need to figure out my life. Look at all the ...
# 123              0  Sir, I sure hope you don't manage a company or...
# 338              0  Just bought a paper planner! Hoping it and goo...
#
#                tweet_id  cecilia_proba  vanessa_proba  deniise_proba
# 11   375511218716286976       0.176034       0.765964       0.058002
# 47    35024012887195648       0.138061       0.720472       0.141467
# 4    453787730426621952       0.192774       0.696613       0.110613
# 584          1267920104       0.221683       0.689121       0.089196
# 9    386616049371975680       0.201197       0.685600       0.113203
# 824           958593087       0.221097       0.680583       0.098320
# 827           951389174       0.239252       0.671230       0.089518
# 463          3162305078       0.233047       0.670867       0.096087
# 699          1083531237       0.257338       0.666151       0.076511
# 88    13741253984256000       0.254823       0.652025       0.093152
# 719          1073967516       0.230476       0.651869       0.117655
# 226         19603406575       0.277091       0.645451       0.077457
# 963           791287072       0.304355       0.639666       0.055980
# 321          7623035991       0.289197       0.631822       0.078981
# 64    23601941602897920       0.252688       0.630951       0.116361
# 199         21783254003       0.288904       0.625278       0.085818
# 478          2540992424       0.255917       0.620508       0.123574
# 694          1091189612       0.295878       0.619886       0.084237
# 215         20317494756       0.272227       0.604663       0.123111
# 956           815173097       0.327232       0.602646       0.070122
# 526          1646768412       0.308320       0.601675       0.090005
# 252         15899494036       0.291390       0.596672       0.111938
# 311          8257698733       0.323706       0.596073       0.080221
# 269         12837311795       0.277504       0.595576       0.126920
# 212         20367311460       0.332306       0.595138       0.072556
# 687          1098604828       0.322319       0.592145       0.085536
# 581          1284486022       0.315242       0.591270       0.093488
# 481          2441836219       0.295157       0.587852       0.116990
# 559          1392270890       0.283183       0.587449       0.129367
# 243         18367785035       0.299746       0.585127       0.115127
# ..                  ...            ...            ...            ...
# 439          3619982095       0.355190       0.519232       0.125578
# 92    12647470471323649       0.368474       0.519147       0.112379
# 697          1087353766       0.379416       0.517338       0.103246
# 277         11280953489       0.378577       0.516865       0.104558
# 742          1052932130       0.388348       0.514858       0.096795
# 132         28824783792       0.358767       0.513884       0.127349
# 375          4906558496       0.364345       0.513628       0.122027
# 129         29214542511       0.398287       0.513454       0.088259
# 32    98581235038830592       0.388827       0.511869       0.099305
# 65    22091898579587072       0.352923       0.511580       0.135496
# 864           923827916       0.401269       0.510911       0.087821
# 103    7547858710429696       0.366731       0.509946       0.123323
# 249         16122511538       0.427720       0.509806       0.062475
# 188         22188935686       0.331679       0.508757       0.159563
# 337          6519006049       0.386941       0.508338       0.104721
# 444          3523108555       0.378805       0.508212       0.112983
# 202         21365493787       0.379585       0.507172       0.113244
# 725          1066691486       0.383832       0.506524       0.109644
# 854           928852949       0.305959       0.506078       0.187963
# 524          1724381003       0.369799       0.505160       0.125041
# 583          1272796282       0.399966       0.504900       0.095134
# 430          3751272106       0.420114       0.504471       0.075416
# 438          3650380203       0.392202       0.502767       0.105031
# 159         25710472238       0.356056       0.502598       0.141346
# 307          8648661524       0.362166       0.502533       0.135301
# 37    61120878456487937       0.418222       0.502031       0.079747
# 769          1020447484       0.376692       0.501593       0.121715
# 728          1063609666       0.417805       0.501572       0.080623
# 123         29584375477       0.340417       0.501283       0.158300
# 338          6446382885       0.397245       0.501248       0.101507
#
# [134 rows x 9 columns]

# %%
student_tweets[(student_tweets['handle'] == 'deniise') & (student_tweets['vanessa_proba'] > .5)].sort_values(by="vanessa_proba", ascending=False)
# Out:
#                          created_at   handle                   mined_at  \
# 26   Fri Aug 19 18:34:45 +0000 2016  deniise 2016-09-19 16:18:29.471354
# 528  Sun Oct 11 22:48:24 +0000 2015  deniise 2016-09-19 16:18:30.740458
# 555  Fri Oct 02 08:09:53 +0000 2015  deniise 2016-09-19 16:18:30.740548
# 549  Sat Oct 03 16:30:05 +0000 2015  deniise 2016-09-19 16:18:30.740528
# 570  Fri Sep 25 19:56:38 +0000 2015  deniise 2016-09-19 16:18:30.740598
# 376  Sun Jan 31 11:15:14 +0000 2016  deniise 2016-09-19 16:18:30.166440
# 346  Wed Feb 10 06:28:29 +0000 2016  deniise 2016-09-19 16:18:30.166331
# 367  Fri Feb 05 23:19:04 +0000 2016  deniise 2016-09-19 16:18:30.166407
# 536  Fri Oct 09 01:24:09 +0000 2015  deniise 2016-09-19 16:18:30.740485
# 331  Thu Feb 18 04:00:06 +0000 2016  deniise 2016-09-19 16:18:30.166275
# 580  Tue Sep 22 23:02:22 +0000 2015  deniise 2016-09-19 16:18:30.740631
# 315  Tue Feb 23 04:26:23 +0000 2016  deniise 2016-09-19 16:18:30.166218
# 43   Wed Aug 03 15:52:48 +0000 2016  deniise 2016-09-19 16:18:29.471439
# 203  Tue May 10 01:13:12 +0000 2016  deniise 2016-09-19 16:18:30.165796
# 80   Sat Jul 16 15:38:06 +0000 2016  deniise 2016-09-19 16:18:29.471633
# 368  Wed Feb 03 03:42:37 +0000 2016  deniise 2016-09-19 16:18:30.166411
# 214  Thu Apr 28 23:47:57 +0000 2016  deniise 2016-09-19 16:18:30.165838
# 514  Sun Oct 18 06:16:53 +0000 2015  deniise 2016-09-19 16:18:30.740410
# 416  Fri Jan 22 01:29:21 +0000 2016  deniise 2016-09-19 16:18:30.740073
# 70   Thu Jul 21 19:53:55 +0000 2016  deniise 2016-09-19 16:18:29.471583
# 56   Fri Jul 29 05:43:57 +0000 2016  deniise 2016-09-19 16:18:29.471508
# 413  Fri Jan 22 02:44:15 +0000 2016  deniise 2016-09-19 16:18:30.740063
# 468  Fri Nov 20 20:14:23 +0000 2015  deniise 2016-09-19 16:18:30.740254
# 251  Sun Apr 10 01:59:39 +0000 2016  deniise 2016-09-19 16:18:30.165981
# 17   Wed Aug 24 20:42:51 +0000 2016  deniise 2016-09-19 16:18:29.471308
# 44   Wed Aug 03 03:41:21 +0000 2016  deniise 2016-09-19 16:18:29.471444
# 142  Wed Jun 01 18:09:46 +0000 2016  deniise 2016-09-19 16:18:29.471989
# 73   Thu Jul 21 07:15:08 +0000 2016  deniise 2016-09-19 16:18:29.471598
# 196  Tue May 10 22:19:44 +0000 2016  deniise 2016-09-19 16:18:30.165767
# 12   Tue Sep 06 15:42:20 +0000 2016  deniise 2016-09-19 16:18:29.471256
# ..                              ...      ...                        ...
# 213  Fri Apr 29 19:16:08 +0000 2016  deniise 2016-09-19 16:18:30.165834
# 535  Fri Oct 09 02:50:30 +0000 2015  deniise 2016-09-19 16:18:30.740481
# 205  Mon May 09 18:30:12 +0000 2016  deniise 2016-09-19 16:18:30.165803
# 304  Sat Feb 27 03:16:42 +0000 2016  deniise 2016-09-19 16:18:30.166176
# 29   Sat Aug 13 03:46:03 +0000 2016  deniise 2016-09-19 16:18:29.471370
# 499  Wed Oct 28 01:31:49 +0000 2015  deniise 2016-09-19 16:18:30.740360
# 298  Wed Mar 02 06:04:56 +0000 2016  deniise 2016-09-19 16:18:30.166154
# 486  Tue Nov 10 03:44:45 +0000 2015  deniise 2016-09-19 16:18:30.740315
# 421  Tue Jan 19 04:11:36 +0000 2016  deniise 2016-09-19 16:18:30.740091
# 288  Mon Mar 14 17:56:21 +0000 2016  deniise 2016-09-19 16:18:30.166118
# 0    Wed Sep 14 05:16:58 +0000 2016  deniise 2016-09-19 16:18:29.471142
# 455  Fri Dec 04 06:56:17 +0000 2015  deniise 2016-09-19 16:18:30.740208
# 283  Fri Mar 18 02:23:22 +0000 2016  deniise 2016-09-19 16:18:30.166099
# 439  Thu Jan 07 18:04:27 +0000 2016  deniise 2016-09-19 16:18:30.740153
# 433  Tue Jan 12 04:50:46 +0000 2016  deniise 2016-09-19 16:18:30.740133
# 162  Sun May 22 21:03:24 +0000 2016  deniise 2016-09-19 16:18:29.472115
# 573  Fri Sep 25 11:12:44 +0000 2015  deniise 2016-09-19 16:18:30.740608
# 432  Wed Jan 13 06:25:30 +0000 2016  deniise 2016-09-19 16:18:30.740129
# 406  Fri Jan 22 22:20:19 +0000 2016  deniise 2016-09-19 16:18:30.740038
# 334  Wed Feb 17 18:33:54 +0000 2016  deniise 2016-09-19 16:18:30.166286
# 410  Fri Jan 22 08:04:15 +0000 2016  deniise 2016-09-19 16:18:30.740052
# 32   Sat Aug 13 02:43:22 +0000 2016  deniise 2016-09-19 16:18:29.471385
# 154  Sun May 29 03:07:39 +0000 2016  deniise 2016-09-19 16:18:29.472070
# 9    Wed Sep 07 23:29:35 +0000 2016  deniise 2016-09-19 16:18:29.471228
# 524  Thu Oct 15 04:01:17 +0000 2015  deniise 2016-09-19 16:18:30.740444
# 431  Wed Jan 13 06:26:54 +0000 2016  deniise 2016-09-19 16:18:30.740126
# 286  Thu Mar 17 19:43:51 +0000 2016  deniise 2016-09-19 16:18:30.166109
# 270  Sun Mar 27 22:14:45 +0000 2016  deniise 2016-09-19 16:18:30.166051
# 328  Fri Feb 19 23:27:36 +0000 2016  deniise 2016-09-19 16:18:30.166264
# 173  Sat May 21 21:27:53 +0000 2016  deniise 2016-09-19 16:18:29.472244
#
#      retweet_count                                               text  \
# 26               0  thanks for the suggestion quora https://t.co/m...
# 528              1  KATE MCKINNON AS DANA SCULLY http://t.co/xaT97...
# 555              0  Studying Obama's winning digital campaigns, th...
# 549            950  RT @Salon: Thank you, @fart, for one of the fu...
# 570              0  When people I've known for months meet my drun...
# 376              0  yo, it's got to be cause I'm seasoned/haters g...
# 346              0  my fav is when they add "OBVIOUSLY YOU AREN'T ...
# 367              0  great Venn diagram of interests here https://t...
# 536              0  all right all right all right http://t.co/fI48...
# 331              0  important questions: does anyone actually like...
# 580              1          @shrugemoji often! http://t.co/d0mxIwFhIA
# 315             35   RT @ShameusSeamus: 📕📕📕 http://t.co/X9GatyDses
# 43               1  Clear your calendar! Women in Product - August...
# 203             16  She stood here this morning while I was gettin...
# 80               1   the new Instagram algorithm has ruined my summer
# 368              0  This election cycle I've noticed that I kinda ...
# 214              0              my whole life https://t.co/zTUaAsrEIa
# 514              0              @twelveoclocke http://t.co/g2Z7ZC55FY
# 416              0  HELP I JUST SLACKED THIS TO MY BOSS AND HE DID...
# 70               0       jay's verse is trump https://t.co/As5PuATE5l
# 56           64929  RT @ingridostby: bill: hey hill check this out...
# 413              0  wow! how much $$$ did it set u back https://t....
# 468           4829  RT @HuffingtonPost: We apologize for the origi...
# 251              0    Life is a rich tapestry https://t.co/UXJt24EkJf
# 17               1  I can't believe I hadn't seen this yet https:/...
# 44               0        my new favorite app https://t.co/pIsFrEgccM
# 142              1                       YES! https://t.co/joY21qqF6T
# 73               0               the nails 😍 https://t.co/7eXRKkxKJw
# 196           6717  RT @BAKKOOONN: the dogs fuckin found out about...
# 12               0  I'm from N.E.R.D. / aren't you Brit-ney https:...
# ..             ...                                                ...
# 213              0  we enjoy having fun at work https://t.co/lGSoR...
# 535           2253         RT @beehivesy: for whom the hotline blings
# 205           3192  RT @iLoveshawn5000: Uber driver jus ran a red ...
# 304              0  why does every Carly Rae Jepsen song make me f...
# 29               0                    hot tea https://t.co/Tp267xXXlm
# 499            224  RT @leighalexander: confused by diversity stuf...
# 298           3540  RT @bootymath: *about to fuck*\nmy safe word i...
# 486             13  RT @honeyedheart: *kicks at the dirt* had this...
# 421              0  "Omg #tbt before I met my hubby" https://t.co/...
# 288              0  @jmkrisko *bergen cackle* *bergen cackle* *ber...
# 0                0  discovered an iOS 10 bug and now I literally c...
# 455           1114  RT @RL_Stine: I want to apologize for the horr...
# 283              0            @DanaSchwartzzz your car has been towed
# 439              0                        @lonelydandruff godlike imo
# 433              1  Maybe dear prudence didn't want to "come out t...
# 162            279  RT @kendrawcandraw: Dudes make fun of girls fo...
# 573              0  Cool pope is responsible for the branding/mark...
# 432             94  Just learned humpbacks scream at 180 db when t...
# 406              1  "All I want is to be the second person @kanyew...
# 334              0  please read this entire thread i'm dying https...
# 410              0  your love songs playlist is incomplete without...
# 32               0  just chopped off my long black acrylics &amp; ...
# 154           1208  RT @IAMANITABAKER: ... who turned  little Mile...
# 9                0     honestly what the fuck https://t.co/PpLhxpcNRh
# 524              0  @MissLoreleiLee this is wonderful! Your writin...
# 431              0                                         and dating
# 286              0            welcome back mo https://t.co/VqRbgddWrF
# 270              0  My cousins and I just explained upper deckers ...
# 328            597  RT @SortaBad: [knife fight]\n\nTrump: I brough...
# 173              0  Manhattan, may 2012: a guy selling his mixtape...
#
#                tweet_id  cecilia_proba  vanessa_proba  deniise_proba
# 26   766704974759723008       0.071407       0.770974       0.157619
# 528  653341407097188352       0.198481       0.699471       0.102048
# 555  649858830633824256       0.205888       0.695787       0.098325
# 549  650347095312990208       0.161160       0.695261       0.143579
# 570  647499973018300416       0.191042       0.694465       0.114492
# 376  693754404558614528       0.152214       0.685417       0.162369
# 346  697306120977649664       0.143985       0.683889       0.172126
# 367  695748505596354560       0.128102       0.681980       0.189918
# 536  652293440839880704       0.172901       0.677347       0.149752
# 331  700167883985256448       0.086985       0.673641       0.239374
# 580  646459550720094208       0.154724       0.663287       0.181989
# 315  701986436589826050       0.070514       0.662219       0.267267
# 43   760866015391518720       0.135436       0.657358       0.207207
# 203  729841687988604930       0.192486       0.653568       0.153946
# 80   754339331280560128       0.231209       0.651623       0.117168
# 368  694727664284758016       0.236045       0.651502       0.112453
# 214  725833967203569664       0.084953       0.647738       0.267309
# 514  655628599890804736       0.146743       0.647307       0.205950
# 416  690345472444219393       0.132354       0.646882       0.220764
# 70   756215649416818688       0.119948       0.645044       0.235008
# 56   758900852455124992       0.199615       0.644318       0.156067
# 413  690364323760361473       0.139997       0.644210       0.215793
# 468  667798163479130112       0.138508       0.643061       0.218431
# 251  718981738551087105       0.138202       0.636964       0.224834
# 17   768549152414326784       0.148996       0.635258       0.215746
# 44   760681937069498368       0.063128       0.631614       0.305259
# 142  738070048871305216       0.047699       0.631127       0.321174
# 73   756024694453641220       0.101909       0.629875       0.268217
# 196  730160420992909312       0.166920       0.622763       0.210317
# 12   773184568299880449       0.142676       0.620089       0.237235
# ..                  ...            ...            ...            ...
# 213  726127947950612480       0.164577       0.513816       0.321607
# 535  652315169310183424       0.173690       0.513129       0.313181
# 205  729740266408579072       0.260627       0.513105       0.226268
# 304  703418452296364032       0.228188       0.512758       0.259054
# 29   764307001278996480       0.203186       0.512350       0.284464
# 499  659180737111851009       0.177905       0.511768       0.310328
# 298  704910339918467072       0.276755       0.511534       0.211711
# 486  663925233703780356       0.260853       0.510553       0.228594
# 421  689299139851468800       0.110969       0.509754       0.379277
# 288  709438029534920704       0.270697       0.509611       0.219692
# 0    775926290113114113       0.379581       0.509035       0.111384
# 455  672670741863600128       0.198066       0.508984       0.292950
# 283  710652786187198464       0.341260       0.508647       0.150093
# 439  685160080069668864       0.280883       0.508327       0.210790
# 433  686772283583533056       0.362462       0.507426       0.130112
# 162  734489864427732992       0.171128       0.507409       0.321462
# 573  647368131795550209       0.276841       0.506953       0.216205
# 432  687158510543491072       0.251867       0.506827       0.241306
# 406  690660289281286145       0.305110       0.506430       0.188459
# 334  700025395203026944       0.126683       0.505881       0.367436
# 410  690444851293360128       0.322863       0.505538       0.171599
# 32   764291226065514496       0.234645       0.504895       0.260460
# 154  736755856428011520       0.133894       0.504568       0.361538
# 9    773664541993422848       0.105378       0.504060       0.390562
# 524  654507311570927616       0.248156       0.503874       0.247970
# 431  687158865247494144       0.246628       0.503172       0.250199
# 286  710552247113879552       0.152996       0.502789       0.344215
# 270  714214099958140929       0.353162       0.502512       0.144326
# 328  700824081440976897       0.312008       0.502439       0.185553
# 173  734133638019702784       0.208998       0.501283       0.289719
#
# [189 rows x 9 columns]

# %%
student_tweets[(student_tweets['handle'] == 'Vanessa Grass') & (student_tweets['cecilia_proba'] > .5)].sort_values(by="cecilia_proba", ascending=False)
# Out:
#                           created_at         handle  \
# 1057  Sat Jul 26 19:33:14 +0000 2014  Vanessa Grass
# 573   Sun Aug 23 20:39:50 +0000 2015  Vanessa Grass
# 1078  Tue Jul 22 03:38:24 +0000 2014  Vanessa Grass
# 587   Thu Aug 13 20:08:30 +0000 2015  Vanessa Grass
# 1485  Tue Apr 29 00:30:05 +0000 2014  Vanessa Grass
#
#                        mined_at  retweet_count  \
# 1057 2016-09-19 16:18:37.662977              0
# 573  2016-09-19 16:18:36.378094              0
# 1078 2016-09-19 16:18:37.663050              0
# 587  2016-09-19 16:18:36.378148              0
# 1485 2016-09-19 16:18:38.653814              0
#
#                                                    text            tweet_id  \
# 1057                              Today is a great day.  493116855783915521
# 573   Just booked my flight to Portland for @xoxo an...  635552048277139456
# 1078  @postobject @MakeshiftSoc dang, I work in Sunn...  491427012095926272
# 587   Today we got chair massages AND pupusas at wor...  631920282156949504
# 1485  Today was a good day because I got to tween so...  460939039810387970
#
#       cecilia_proba  vanessa_proba  deniise_proba
# 1057       0.660448       0.280438       0.059114
# 573        0.617015       0.301389       0.081596
# 1078       0.583399       0.357188       0.059413
# 587        0.543074       0.359195       0.097731
# 1485       0.533443       0.391663       0.074894

# %% [markdown]
# ### 2. Implement K-Folds or test/train split.
#
# Double check that you are getting random data before moving forward.  What would happen if you over sample Trump more than Sanders?

# %% [markdown]
# ### 3. Mine more Tweets that aren't in your data set
# Or use the hold-out method to do a proper test.  Refer back to our advanced classification evaluation lesson if you need to.

# %% [markdown]
# ### 4. Check your classification report
# How's precision / recall of your model?

# %% [markdown]
# ### 5.  Change out your TFIDF vectorizer for CountVectorizer.
# How has this impacted your mode performance at all?

# %% [markdown]
# ### 6.  Implement a different classification method such as random forrests.
# Or pick one of your favorites

# %% [markdown]
# ### 7.  Try to remove stopwords from your text during your preprocessing step
#
# Then double check your classfication report.  Have things improved?

# %% [markdown]
# ### 8.  Try removing samples that have links or that are obviously just announcements or "noise" that doesn't appear to represent "True" tweets by the authors.

# %% [markdown]
# ### 9. What are some contrasting words or phrases that you can see between the ngrams for each author?

# %% [markdown]
# ### 10.  What do you think you can do to improve the scores further?

# %% [markdown]
# ### 11. **BONUS** Using TextBlob, add a sentiment feature to your dataset.

# %% [markdown]
# ### 12. BONUS BONUS Apply PCA to your text features
# Is this effective? (ie: we could talk about LDA here a little bit)

# %% [markdown]
# ## Closing
#
# - What where the most impactful changes that helped your models?
# - What do you think would happen if we had more Trump Tweets than Sanders?
# - What other projects might you think to apply these problems against?
