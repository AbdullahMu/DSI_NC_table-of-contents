# %%
import pandas as pd
import numpy as np

# %%
data = ufo = pd.read_csv('https://raw.githubusercontent.com/sinanuozdemir/SF_DAT_17/master/data/ufo.csv')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
def myfunction(x):
    return 0

# def --> lambda

# %%
def tmp_func(subset):
    subset['new_shape'] = subset['Shape Reported'].map(myfunction)
    return subset

ufo.groupby('City').apply(tmp_func)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
group_colors = ufo.groupby(['City','State'])['Colors Reported']
group_colors.apply(lambda x: len(np.unique(x))).reset_index()
# Out:
#                                       City State  Colors Reported
# 0                               ((HOAX??))    PA                1
# 1                 ((Unspecified location))    IL                1
# 2                     (City not specified)    MO                1
# 3            (above mountains in airplane)    UT                1
# 4                                Abbeville    LA                1
# 5                                Abbeville    SC                2
# 6                                 Aberdeen    MD                1
# 7                                 Aberdeen    NC                1
# 8                                 Aberdeen    NJ                1
# 9                                 Aberdeen    OH                1
# 10                                Aberdeen    SD                2
# 11                                Aberdeen    WA                3
# 12                                 Abilene    KS                2
# ...

# %%
shape_counts.shape
# Out:
# (18263, 3)
